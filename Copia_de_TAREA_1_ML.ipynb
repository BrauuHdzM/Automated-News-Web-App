# %% [markdown]
# <a href="https://colab.research.google.com/github/BrauuHdzM/Automated-News-Web-App/blob/master/Copia_de_TAREA_1_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bienvenido al curso de Python de Zero2Hero.
#
# El proposito de estos notebooks es que puedas ir trabajando lo que vas aprendiendo en clase hasta ahora

# %% [markdown]
# Lo primero que tendras que hacer para que el avance que vayas haciendo, para esta tarea se guarde en tu drive es lo siguiente
#
# Ve archivo y selecciona la opción guardar una copia en drive
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Una vez que ya has hecho esto, se deberia abrir una copia de este notebook en una nueva pestaña, ahora estas listo para comenzar a trabajar.

# %% [markdown]
# ##Repaso de los conceptos aprendidos.
#
#
# Hagamos un repaso de los conceptos que hemos aprendido en esta semana.

# %% [markdown]
# Hasta ahora hemos visto los siguientes temas 👽 , espero que te hayan quedado claros si algun tema no te queda claro o tienes alguna duda no tengas miedo en preguntar, el curso es para que podamos aprender juntos ♥

# %% [markdown]
# **Sintaxis básica de Python:** Python es un lenguaje de programación que se distingue por su simplicidad y claridad. La sintaxis de Python es fácil de entender debido a su diseño limpio.

# %%
print("Hola, mundo!")  # Esta es una instrucción simple en Python que imprime "Hola, mundo!" en la consola
# Out:
# Hola, mundo!

# %% [markdown]
# La función **print()** es una de las funciones incorporadas más utilizadas en Python. Es la manera principal que tiene un programa de Python para interactuar con el usuario mediante la salida de texto.
#
# La función **print()** toma uno o más argumentos y los convierte en una representación en forma de cadena, luego envía esa cadena a la salida estándar (por lo general, la consola o terminal desde la que se ejecuta el programa). Después de imprimir todos los argumentos, **print()** agrega automáticamente un salto de línea para que la próxima salida comience en una nueva línea.

# %% [markdown]
# **print()** también puede tomar múltiples argumentos, que imprimirá uno tras otro, separados por un espacio. Aquí tienes un ejemplo:

# %%
nombre = "María"
edad = 30
print("Hola, mi nombre es ",nombre, "y tengo", edad, "años.")
# Out:
# Hola, mi nombre es María y tengo 30 años.

# %% [markdown]
# Cuando ejecutes este código, verás la frase "Hola, mi nombre es María y tengo 30 años." en tu consola.
#
# Además, **print()** puede usarse con la función **str.format()** para incrustar valores en una cadena de una manera más legible. Aquí tienes un ejemplo:

# %%
nombre = "María"
edad = 30
print(f"Hola, mi nombre es {} y tengo {} años.".format(nombre, edad))
# Out:
# Hola, mi nombre es María y tengo 30 años.

# %% [markdown]
# Este código produce el mismo resultado que el ejemplo anterior, pero es un poco más fácil de leer y escribir, especialmente cuando se trabaja con muchas variables o con cadenas de texto largas.

# %% [markdown]
# **Función input():** Esta es una función incorporada en Python que se utiliza para recoger la entrada del usuario. La función input() presenta al usuario una línea de texto en la consola y luego espera a que el usuario introduzca algo y pulse la tecla de retorno o enter. Después de que el usuario pulsa enter, la función input() toma todo lo que el usuario ha tecleado y lo devuelve como una cadena

# %%
nombre = input("¿Cómo te llamas? ")
print("Hola, " + nombre + "!")
# Out:
# ¿Cómo te llamas? Benito
# Hola, Benito!

# %% [markdown]
# Cuando ejecutas este código, se te pedirá que introduzcas tu nombre. Después de hacerlo y pulsar enter, el programa te saludará.

# %% [markdown]
# **Función int() con input():** A veces, necesitas que el usuario introduzca un número, no una cadena. Sin embargo, como la función input() siempre devuelve una cadena, tienes que convertir esa cadena en un número. Para hacer eso, puedes usar la función int().

# %% [markdown]
# Función int() con input(): A veces, necesitas que el usuario introduzca un número, no una cadena. Sin embargo, como la función input() siempre devuelve una cadena, tienes que convertir esa cadena en un número. Para hacer eso, puedes usar la función int().

# %%
edad = int(input("¿Cuántos años tienes? "))
años_hasta_cien = 100 - edad
print("¡Te faltan " + str(años_hasta_cien) + " años para cumplir 100!")
# Out:
# ¿Cuántos años tienes? 12
# ¡Te faltan 88 años para cumplir 100!

# %% [markdown]
# Cuando ejecutas este código, se te pedirá que introduzcas tu edad. Después de hacerlo y pulsar enter, el programa te dirá cuántos años te faltan para cumplir 100.
#
# En este ejemplo, si introduces algo que no es un número (como "veinte" en lugar de "20"), obtendrás un error porque la función **int()** no puede convertir "veinte" en un número.
#
# También es importante mencionar que la función **int()** solo convierte cadenas a números enteros. Si necesitas un número de punto flotante (un número que puede tener decimales), puedes usar la función **float() **en su lugar. Por ejemplo, **float(input())** te permitiría que el usuario introduzca un número con decimales.

# %%
peso = float(input("Por favor, introduce tu peso en kilogramos: "))
altura = float(input("Ahora, introduce tu altura en metros: "))
imc = peso / (altura ** 2)
print("Tu índice de masa corporal (IMC) es: " + str(imc))

# %% [markdown]
# En este ejemplo, el programa pide al usuario que introduzca su peso y altura, y luego calcula el índice de masa corporal (IMC), que es una medida de la grasa corporal basada en el peso y la altura.
#
# Tanto el peso como la altura pueden ser números de punto flotante (es decir, pueden tener decimales), por eso usamos float(input()) en lugar de int(input()).
#
# Ten en cuenta que la fórmula para calcular el IMC es peso / altura^2. El operador ** en Python es para exponentes, por lo que altura ** 2 significa "altura al cuadrado".
#
# Finalmente  antes de imprimir el IMC, lo convertimos de nuevo a una cadena con la función str(), ya que no se pueden concatenar directamente cadenas y números en Python.

# %% [markdown]
# **Variables:** En Python, las variables se usan para almacenar valores. No necesitas declarar el tipo de la variable porque Python es dinámicamente tipado
#
# En otros lenguajes por ejemplo C++, hay que decir con que tipo de variable estas trabajando , esto no es necesario en Python

# %%
x = 5  # Aquí, x es una variable que almacena el valor entero 5   (Esto es una variable de tipo entero)
nombre = "Juan"  # Aquí, nombre es una variable que almacena la cadena "Juan" (Esta es una variable de tipo string)

# %% [markdown]
# **Tipos de Datos:** Python maneja varios tipos de datos. Los más comunes son los números enteros (int), los números de punto flotante (float), las cadenas de caracteres (str), las listas (list), los diccionarios (dict), y los booleanos (bool).

# %%
entero = 10  # Esto es un entero
flotante = 20.5  # Esto es un número de punto flotante
cadena = "Hola"  # Esto es una cadena de caracteres
lista = [1, 2, 3]  # Esto es una lista de enteros
diccionario = {"manzana": 1, "banana": 2}  # Esto es un diccionario
booleano = True  # Esto es un booleano

# %% [markdown]
# Observa que para indicar que estamos trabajando con una lista usamos []\
# Para trabajar con un diccionario usamos {}\
# Mientras que las strings se caracterizan por usar las dobles comillas " "

# %% [markdown]
# **Operadores:** Los operadores se utilizan para realizar operaciones sobre variables y valores. Python tiene operadores de asignación, operadores aritméticos, operadores de comparación, operadores lógicos, entre otros.

# %%
a = 10  # El operador "=" es un operador de asignación
b = a + 5  # Los operadores "+" y "=" son operadores aritméticos
resultado = (a == b)  # El operador "==" es un operador de comparación, el resultado es un booleano (True o False)
resultado = (a < b and b > a)  # Los operadores "<", ">", "and" son operadores de comparación y lógicos

# %% [markdown]
# **Condicionales:** Las declaraciones condicionales son usadas para ejecutar código si una cierta condición es verdadera.

# %%
if a > b:  # Si "a" es mayor que "b"
    print("a es mayor que b")
elif a < b:  # Si "a" es menor que "b"
    print("a es menor que b")
else:  # Si ninguna de las condiciones anteriores es verdadera
    print("a es igual a b")

# %% [markdown]
# Las estructuras condicionales en Python te permiten realizar diferentes acciones basadas en ciertas condiciones. Esto significa que puedes controlar el flujo de tu programa basándote en los resultados de las expresiones que evalúas.
#
# Hay tres formas básicas de estructuras condicionales:

# %% [markdown]
# **if** : Esta es la forma más básica. Evalúa una condición y, si esa condición es verdadera (True), ejecuta el bloque de código que sigue.

# %%
x = 10
if x > 0:  # Si x es mayor que 0
    print("x es un número positivo")
# Out:
# x es un número positivo

# %% [markdown]
# En este caso, como x es de hecho mayor que 0, se imprimirá "x es un número positivo".
#
# Ve que pasa si cambias los valores de x a por ejemplo x=0 o x=-1 , ¿que corregirias para que x=0 pase como un número positivo?

# %% [markdown]
# **elif:** Esta es una forma de decir "si la(s) condición(es) anterior(es) no era(n) verdadera(s), entonces intenta esta condición". Puedes tener tantos elif en tu código como quieras.

# %%
x = 10
if x > 100:  # Si x es mayor que 100
    print("x es mayor que 100")
elif x > 50:  # Si x es mayor que 50
    print("x es mayor que 50")
elif x > 0:  # Si x es mayor que 0
    print("x es mayor que 0")
# Out:
# x es mayor que 0

# %% [markdown]
# Intenta ver que pasa, para otros valores de **x**

# %% [markdown]
# **else:** Esta es una forma de decir "si ninguna de las condiciones anteriores era verdadera, entonces haz esto". Solo puedes tener un else en tu bloque de código.

# %%
x = -10
if x > 0:  # Si x es mayor que 0
    print("x es un número positivo")
else:  # Si ninguna de las condiciones anteriores es verdadera
    print("x no es un número positivo")
# Out:
# x no es un número positivo

# %% [markdown]
# En este caso, como $x$ no es mayor que $0$, se imprimirá "$x$ no es un número positivo".
#
# Estas estructuras pueden ser tan simples o tan complejas como necesites. Puedes anidarlas (poner una estructura dentro de otra) para hacer evaluaciones más complejas.
#
# Por ejemplo:

# %%
x = 10
y = 20
if x > 0:  # Si x es mayor que 0
    if y > 0:  # Si y es mayor que 0
        print("x y y son números positivos")
    else:  # Si y no es mayor que 0
        print("x es un número positivo, y no lo es")
else:  # Si x no es mayor que 0
    print("x no es un número positivo")

# %% [markdown]
# En este caso, imprimirá **"x y y son números positivos".**

# %% [markdown]
# #TAREAS
#
# Para estas tareas no recomiendo que uses Chat gpt , este lo usaremos solo para tareas más complejas, trata de ir razonando y diseñar tu propio programa, puedes buscar ayuda en internet si asi lo requieres.

# %% [markdown]
# Calculadora Básica:
#
# Escribe un programa que pida al usuario dos números y luego le pregunte qué operación quiere realizar: suma, resta, multiplicación o división. Asegúrate de usar estructuras condicionales para decidir qué operación realizar.

# %%
numero1 = float(input("Ingrese el primer numero "))
numero2 = float(input("Ingrese el segundo numero "))
print("Ingrese el la operación que desea realizar, suma, resta, multiplicacion o division")
operacion = input()
if operacion == "suma":
  print(numero1 + numero2)
elif operacion == "resta":
  print(numero1 - numero2)
elif operacion == "multiplicacion":
  print(numero1 * numero2)
elif operacion == "division":
  print(numero1 / numero2)
# Out:
# Ingrese el primer numero 34
# Ingrese el segundo numero 12
# Ingrese el la operación que desea realizar, suma, resta, multiplicacion o division
# suma
# 46.0

# %% [markdown]
# Tarifas de Entrada al cine:
#
#  Un cine cobra diferentes tarifas de entrada según la edad de la persona. Si la persona es menor de 3 años, su entrada es gratuita. Si tienen entre 3 y 12 años, la entrada cuesta $10$. Si tienen más de 12 años, la entrada cuesta $15$. Escribe un programa que pida al usuario su edad y luego imprima cuánto tienen que pagar.

# %%
edad = int(input("Ingrese su edad "))

if edad < 3:
  print("Entra gratis")
elif edad >= 3 and edad <= 12
  print("La entrada cuesta $10")
elif edad > 12:
  print("La entrada cuesta $15")

# %% [markdown]
# Año Bisiesto:
#
# Escribe un programa que pida al usuario un año y luego imprima si ese año es bisiesto o no. Recuerda que un año es bisiesto si es divisible por 4, pero no si es divisible por 100, a menos que también sea divisible por 400.

# %%
año = int(input("Ingrese el año "))
if año % 4 == 0 and año % 100 != 0 or año % 400 == 0:
  print("El año es bisiesto")
else:
  print("El año no es bisiesto")
# Out:
# Ingrese el año 1700
# El año no es bisiesto

# %% [markdown]
# Problema reto:
#
# Escribe un programa que te regrese los primos del 1 al 100000, recuerda que un número es primo si y solo si es divisible entre 1 y el mismo número.
#
# Por ejemplos los números $2,3,5,7,11,13$ son primos, pero el número $15$ no es primo ya que es divisible entre $2$ y $3$
#
#
# Para ver que un número $n$ es primo, solo hay que fijarse que los primos menores que $\sqrt n$, explica en otra celda de texto ¿por que?, si puedes has la demostración.

# %%
import math

def es_primo(n):
    if n <= 1:
        return False  # Los números menores o iguales a 1 no son primos
    if n <= 3:
        return True  # 2 y 3 son primos
    if n % 2 == 0 or n % 3 == 0:
        return False  # Si es divisible entre 2 o 3, no es primo

    # Comprobar divisibilidad por números primos hasta √n
    limite = int(math.sqrt(n)) + 1
    for i in range(5, limite, 2):  # Iterar por números impares, comenzando en 5
        if n % i == 0:
            return False
    print("el limite es " + str(limite))
    return True

for numero in range (1, 51):
  if es_primo(numero):
    print(numero)
# Out:
# 2
# 3
# el limite es 3
# 5
# el limite es 3
# 7
# el limite es 4
# 11
# el limite es 4
# 13
# el limite es 5
# 17
# el limite es 5
# 19
# el limite es 5
# 23
# el limite es 6
# 29
# el limite es 6
# 31
# el limite es 7
# 37
# el limite es 7
# 41
# el limite es 7
# 43
# el limite es 7
# 47
